# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\om sai compurer1\Desktop\cust satisfaction\cust_satisfaction.csv")

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
Gender ={
    'Male':0, 'Female':1
}

# %%
df['Gender'] = df['Gender'].map(Gender)

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
Customer_Type ={
    'Loyal Customer':0, 'disloyal Customer':1
}

# %%
df['Customer Type']= df['Customer Type'].map(Customer_Type)

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0            0              0  Personal Travel  Eco Plus
# 1            0              1  Business travel  Business
# 2            1              0  Business travel  Business
# 3            1              0  Business travel  Business
# 4            0              0  Business travel  Business
# ...        ...            ...              ...       ...
# 103899       1              1  Business travel       Eco
# 103900       0              0  Business travel  Business
# 103901       0              1  Business travel  Business
# 103902       1              1  Business travel       Eco
# 103903       0              0  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
Type_of_Travel ={
    'Business travel':0, 'Personal Travel':1
}
df['Type of Travel']= df['Type of Travel'].map(Type_of_Travel)

# %%
df['Class'].unique()
Class ={
    'Business':0, 'Eco':1, 'Eco Plus':2
}
df['Class']= df['Class'].map(Class)
df
# Out:
#         Gender  Customer Type  Type of Travel  Class             satisfaction  \
# 0            0              0               1      2  neutral or dissatisfied
# 1            0              1               0      0  neutral or dissatisfied
# 2            1              0               0      0                satisfied
# 3            1              0               0      0  neutral or dissatisfied
# 4            0              0               0      0                satisfied
# ...        ...            ...             ...    ...                      ...
# 103899       1              1               0      1  neutral or dissatisfied
# 103900       0              0               0      0                satisfied
# 103901       0              1               0      0  neutral or dissatisfied
# 103902       1              1               0      1  neutral or dissatisfied
# 103903       0              0               0      0  neutral or dissatisfied
#
# ...

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
satisfaction ={
    'neutral or dissatisfied':0, 'satisfied':1
}
df['satisfaction']= df['satisfaction'].map(satisfaction)
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               1      2             0   13
# 1            0              1               0      0             0   25
# 2            1              0               0      0             1   26
# 3            1              0               0      0             0   25
# 4            0              0               0      0             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       1              1               0      1             0   23
# 103900       0              0               0      0             1   49
# 103901       0              1               0      0             0   30
# 103902       1              1               0      1             0   22
# 103903       0              0               0      0             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  int64
#  1   Customer Type               103904 non-null  int64
#  2   Type of Travel              103904 non-null  int64
#  3   Class                       103904 non-null  int64
#  4   satisfaction                103904 non-null  int64
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(11)
# memory usage: 9.5 MB

# %%
x = df.drop('satisfaction', axis=1)
y = df['satisfaction']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('satisfaction', axis=1), df['satisfaction'], test_size=0.2, random_state=42)

# %%
x_train
# Out:
#         Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 20921        1              0               1      1   59             1046
# 36897        1              1               0      0   40              752
# 8468         0              0               1      1   65              383
# 53490        1              0               1      1   70             2239
# 78687        1              1               0      1   25             1358
# ...        ...            ...             ...    ...  ...              ...
# 54886        0              1               0      1   39              637
# 76820        0              0               1      1   17              646
# 103694       0              0               0      1   46             1197
# 860          1              0               0      1   37              320
# 15795        1              0               1      1   14              351
#
#         Inflight entertainment  Baggage handling  Cleanliness  \
# ...

# %%
y_train
# Out:
# 20921     0
# 36897     0
# 8468      0
# 53490     0
# 78687     0
#          ..
# 54886     0
# 76820     0
# 103694    0
# 860       1
# 15795     0
# Name: satisfaction, Length: 83123, dtype: int64

# %%
x_test
# Out:
#        Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 80638       1              0               1      1   26              861
# 43398       0              0               0      0   22              393
# 32751       1              0               1      1   59              196
# 33571       1              0               1      1   32             1020
# 71287       0              1               0      0   35             1117
# ...       ...            ...             ...    ...  ...              ...
# 8158        0              1               0      0   42              236
# 53718       0              0               1      1   14              558
# 33319       0              0               1      1    9             1005
# 99162       1              0               0      0   45             3234
# 96811       0              0               0      2   31               86
#
#        Inflight entertainment  Baggage handling  Cleanliness  \
# ...

# %%
y_test
# Out:
# 80638    0
# 43398    0
# 32751    0
# 33571    0
# 71287    0
#         ..
# 8158     0
# 53718    0
# 33319    0
# 99162    1
# 96811    1
# Name: satisfaction, Length: 20781, dtype: int64

# %%
df.dropna()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               1      2             0   13
# 1            0              1               0      0             0   25
# 2            1              0               0      0             1   26
# 3            1              0               0      0             0   25
# 4            0              0               0      0             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       1              1               0      1             0   23
# 103900       0              0               0      0             1   49
# 103901       0              1               0      0             0   30
# 103902       1              1               0      1             0   22
# 103903       0              0               0      0             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
from sklearn.svm import SVC
sv = SVC()

# %%
x_train
# Out:
#         Gender  Customer Type  Type of Travel  Class  Age  Flight Distance  \
# 20921        1              0               1      1   59             1046
# 36897        1              1               0      0   40              752
# 8468         0              0               1      1   65              383
# 53490        1              0               1      1   70             2239
# 78687        1              1               0      1   25             1358
# ...        ...            ...             ...    ...  ...              ...
# 54886        0              1               0      1   39              637
# 76820        0              0               1      1   17              646
# 103694       0              0               0      1   46             1197
# 860          1              0               0      1   37              320
# 15795        1              0               1      1   14              351
#
#         Inflight entertainment  Baggage handling  Cleanliness  \
# ...

# %%
x_train.shape
# Out:
# (83123, 11)

# %%
y_train.shape
# Out:
# (83123,)

# %%
print(x_train.dtypes)
# Out:
# Gender                          int64
# Customer Type                   int64
# Type of Travel                  int64
# Class                           int64
# Age                             int64
# Flight Distance                 int64
# Inflight entertainment          int64
# Baggage handling                int64
# Cleanliness                     int64
# Departure Delay in Minutes      int64
# Arrival Delay in Minutes      float64
# dtype: object

# %%
print(x_train.isnull().sum())
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      251
# dtype: int64

# %%
x_train = x_train.fillna(x_train.mean())

# %%
x_train['Arrival Delay in Minutes'] = x_train['Arrival Delay in Minutes'].fillna(x_train['Arrival Delay in Minutes'].mean())

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(x_train.isnull().sum())
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
print(x_test.isnull().sum())
# Out:
# Gender                         0
# Customer Type                  0
# Type of Travel                 0
# Class                          0
# Age                            0
# Flight Distance                0
# Inflight entertainment         0
# Baggage handling               0
# Cleanliness                    0
# Departure Delay in Minutes     0
# Arrival Delay in Minutes      59
# dtype: int64

# %%
x_test = x_test.fillna(x_test.mean())

# %%
lr.predict(x_test)
# Out:
# array([0.3226039 , 0.62751943, 0.21216606, ..., 0.19028965, 0.76368331,
#        0.34747384], shape=(20781,))

# %%
lr.predict(x_train)
# Out:
# array([0.07994697, 0.14561407, 0.0161763 , ..., 0.32221064, 0.76934879,
#        0.28777743], shape=(83123,))

# %%
sv.fit(x_train, y_train)
# Out:
# SVC()

# %%
sv.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 1, 0], shape=(20781,))

# %%
sv.predict(x_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(83123,))

# %%
import imblearn
from imblearn.over_sampling import SMOTE

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtc = DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred = dtc.predict(x_test)
pred
# Out:
# array([0., 0., 0., ..., 1., 1., 1.], shape=(20781,))

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
import joblib
joblib.dump(dtc, 'cust_satisfaction_model.lb')
# Out:
# ['cust_satisfaction_model.lb']

# %%
cust_satisfaction_model = joblib.load('cust_satisfaction_model.lb')

# %%
cust_satisfaction_model
# Out:
# DecisionTreeRegressor()

# %%
cust_satisfaction_model.predict(x_test)
# Out:
# array([0., 0., 0., ..., 1., 1., 1.], shape=(20781,))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris
x ,y = load_iris(return_X_y=True)
from sklearn.naive_bayes import GaussianNB, MultinomialNB
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=7)
Mnb =MultinomialNB()
Mnb.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
Mnb.score(x_test, y_test)
# Out:
# 0.8333333333333334

# %%
from sklearn.cluster import KMeans
km =KMeans()
km.fit(x_train, y_train)
# Out:
# KMeans()

# %%
km.score(x_test, y_test)
# Out:
# -9.296924697199538

# %%
df.to_csv('cust_satisfaction_model_cleaned.csv', index=False)
